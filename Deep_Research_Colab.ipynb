# %% [markdown]
# # 🔬 Deep Research - AI-powered Insight Agent
#
# This notebook runs the Deep Research agent directly in Google Colab.
#
# **Features:**
# - 🎯 Smart search planning
# - 🔄 Two-phase search with gap analysis
# - ✅ Fact checking with source credibility
# - 📊 Multiple report styles
# - 🌍 Multi-language support
#
# ---

# %% [markdown]
# ## Step 1: Enter your OpenAI API Key
#
# Run this cell and enter your API key when prompted.

# %%
import os
from getpass import getpass

# Get API key securely
OPENAI_API_KEY = getpass("🔑 Enter your OpenAI API Key: ")
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

print("✅ API Key set successfully!")

# %% [markdown]
# ## Step 2: Install Dependencies
#
# This will take about 1-2 minutes.

# %%
# !pip install -q gradio openai openai-agents pydantic aiohttp python-dotenv
print("✅ Dependencies installed!")

# %% [markdown]
# ## Step 3: Download Project Files
#
# Clone the repository from GitHub.

# %%
# Clone the repository (replace with your GitHub username)
# !git clone https://github.com/YOUR_USERNAME/deep-research.git
# %cd deep-research
print("✅ Project files downloaded!")

# %% [markdown]
# ## Step 4: Launch the App! 🚀
#
# Run this cell to start the Gradio interface.
#
# **Click the public URL** (ends with `.gradio.live`) to access the app.

# %%
# Import and run
import subprocess
subprocess.run(["python", "app.py"])

# %% [markdown]
# ---
#
# ## 🛠️ Troubleshooting
#
# **"No module named 'agents'"**
# - Run Step 2 again to install dependencies
#
# **"Invalid API Key"**
# - Run Step 1 again and check your key
#
# **App doesn't load**
# - Wait 30 seconds for the public URL to generate
# - Try clicking "Restart runtime" and run all cells again
